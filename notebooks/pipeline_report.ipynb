# %% [markdown]
# # Medical Telegram Warehouse Report
# This notebook template captures interim/final findings, architecture diagrams, and screenshots for the Week 8 challenge.

# %% [markdown]
# ## Checklist
# - Describe data lake folder strategy
# - Paste star schema diagram
# - Summarize dbt test results
# - Insert YOLO insight tables
# - Attach API & Dagster screenshots
